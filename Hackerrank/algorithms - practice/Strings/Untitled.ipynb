# %%
from collections import Counter
def valid(word):
    table = Counter(word)
    counts = [table[i] for i in table]
    counts = Counter(counts)
    print(counts)
    unique, c = [], []
    for i in counts:
        unique.append(i)
        c.append(counts[i])
    if len(c) <= 1:
        return 'YES'
    if len(c) > 2:
        return 'NO'
    one = -1
    if c[0] == 1:
        one = 0
    if c[1] == 1:
        one = 1
    if one != -1 and ((unique[one] == 1) or (unique[one] - 1 == unique[one - 1])):
        return 'YES'
    return 'NO'

# %%
function Counter(array) {
  var count = {};
  array.forEach(val => count[val] = (count[val] || 0) + 1);
  return count;
}

console.log(Counter(list));

# %%
valid('abcccc')
# Out:
# Counter({1: 2, 4: 1})
# 'NO'

# %%
valid('abc')
# Out:
# [1] [3]
# 'YES'

# %%
valid('abccccccc')
# Out:
# [1, 7] [2, 1]
# 'NO'

# %%
valid('aabbccccccc')
# Out:
# [2, 7] [2, 1]
# 'NO'

# %%
valid('aabbcd')
# Out:
# [2, 1] [2, 2]
# 'NO'

# %%
valid('aabbccddeefghi')
# Out:
# [2, 1] [5, 4]
# 'NO'

# %%
valid('aabbbb')
# Out:
# [2, 4] [1, 1]
# 'NO'

# %%
valid('e')
# Out:
# [1] [1]
# 'YES'

# %%
valid('eerrttwwa')
# Out:
# [2, 1] [4, 1]
# 'YES'

# %%
valid('...')
# Out:
# [111, 1] [9, 1]
# 'YES'

# %%
valid('abccc')
# Out:
# [1, 3] [2, 1]
# 'NO'

# %%
valid('...')
# Out:
# [111, 1] [9, 1]
# 'YES'

# %%
valid('...')
